# %%
import pandas as pd

# %%
df1 = pd.read_csv("cases_valid_clean.csv")

# %%
df
# Out:
#                           filename  label             model_used  \
# 0         Uttarakhand_HC_2015_1701      1  x-ai/grok-4-fast:free
# 1        Bombay_HC_BomHC_2017_1744      1  x-ai/grok-4-fast:free
# 2         Bombay_HC_BomHC_1987_396      1  x-ai/grok-4-fast:free
# 3              Kolkata_HC_1961_130      1  x-ai/grok-4-fast:free
# 4               Delhi_HC_2012_2643      1  x-ai/grok-4-fast:free
# ...                            ...    ...                    ...
# 20945             Patna_HC_1925_87      0  x-ai/grok-4-fast:free
# 20946  Consumer_Disputes_2010_4520      1  x-ai/grok-4-fast:free
# 20947             Patna_HC_2008_64      0  x-ai/grok-4-fast:free
# 20948           Delhi_HC_2017_4230      0  x-ai/grok-4-fast:free
# 20949         Rajasthan_HC_2008_74      1  x-ai/grok-4-fast:free
#
#                                             raw_response  \
# 0      {"statutes": ["Wild Life (Protection) Act, 197...
# 1      {"statutes": ["Value Added Tax Act 2002 Sec 45...
# ...

# %%
l = []
for i in range(df.shape[0]):
    l.extend(eval(df.loc[i, "statutes"]))

# %%
from collections import Counter
d = Counter(l)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.DataFrame(list(d.items()), columns=["statutes", "count"])

# Take top 10 by count
top10 = df.sort_values(by="count", ascending=False).head(10)

# Plot with seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x="count", y="statutes", data=top10, palette="viridis")

plt.title("Top 10 Statutes by Count")
plt.xlabel("Count")
plt.ylabel("Statutes")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\apaas\AppData\Local\Temp\ipykernel_10012\2406706103.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="count", y="statutes", data=top10, palette="viridis")

# %%
d
# Out:
# Counter({'IPC Sec 302': 1310,
#          'CrPC Sec 313': 926,
#          'IPC Sec 34': 858,
#          'Consumer Protection Act, 1986': 721,
#          'IPC Sec 323': 707,
#          'CrPC Sec 482': 662,
#          'IPC Sec 307': 575,
#          'IPC Sec 420': 551,
#          'Constitution of India Art 226': 529,
#          'IPC Sec 148': 451,
#          'IPC Sec 149': 434,
#          'IPC Sec 324': 419,
#          'IPC Sec 147': 370,
#          'IPC Sec 498A': 332,
#          'Constitution of India Article 226': 328,
#          'Article 226 of the Constitution of India': 316,
#          'IPC Sec 506': 302,
#          'IPC Sec 406': 287,
#          'CrPC Sec 161': 285,
#          'IPC Sec 120B': 283,
#          'IPC Sec 471': 275,
#          'IPC Sec 468': 274,
#          'IPC Sec 376': 256,
#          'IPC Sec 341': 253,
#          'IPC Sec 201': 241,
#          'IPC Sec 326': 236,
#          'IPC Sec 120-B': 236,
#          'Income Tax Act Sec 143(3)': 233,
# ...

# %%
c = []
for i in range(df1.shape[0]):
    c.extend(eval(df1.loc[i, "charges"]))

# %%
c
# Out:
# ['Illegal possession of animal bones',
#  'Non-payment of VAT on branded tobacco',
#  'Bigamy',
#  'Abetment of Bigamy',
#  'Attempt to Commit Bigamy',
#  'Misconduct',
#  'Riotous and disorderly behaviour',
#  'Acts prejudicial to maintenance of public order',
#  'Violent conduct',
#  'Rash and Negligent Driving',
#  'Declaratory suit for raiyat status',
#  'Recovery of debt under partnership dealings',
#  'Penalty for non-filing of six monthly progress reports under ULC Act exemption order',
#  'Deficiency in Service',
#  'Murder',
#  'Gang Rape',
#  'Theft',
#  'Assault',
#  'Rape',
#  'Kidnapping',
#  'Wrongful Confinement',
#  'Grievous Hurt',
#  'Forgery',
#  'Cheating',
#  'Wrongful availment of small scale exemption',
#  'Non-payment of central excise duty',
#  'Rash and negligent driving',
#  'Causing hurt by rash and negligent act',
#  'Criminal Breach of Trust',
#  'Criminal Breach of Trust by Public Servant',
#  'Recovery of possession of land',
# ...

# %%
dc = Counter(c)

# %%
dc
# Out:
# Counter({'Murder': 1569,
#          'Deficiency in Service': 1182,
#          'Cheating': 759,
#          'Forgery': 656,
#          'Voluntarily causing hurt': 533,
#          'Cruelty': 499,
#          'Breach of Contract': 499,
#          'Rioting': 466,
#          'Criminal Conspiracy': 401,
#          'Fraud': 399,
#          'Rash and negligent driving': 395,
#          'Attempt to Murder': 394,
#          'Theft': 339,
#          'Rape': 337,
#          'Criminal Breach of Trust': 333,
#          'Criminal intimidation': 319,
#          'Dishonour of Cheque': 283,
#          'Criminal Intimidation': 270,
#          'Unfair Trade Practice': 268,
#          'Rioting armed with deadly weapon': 260,
#          'Voluntarily Causing Hurt': 234,
#          'Attempt to murder': 233,
#          'Permanent Injunction': 232,
#          'Kidnapping': 212,
#          'Misconduct': 198,
#          'Unlawful assembly': 196,
#          'Criminal conspiracy': 194,
# ...

# %%
cf = pd.DataFrame(list(dc.items()), columns=["charges", "count"])

# Take top 10 by count
top10 = cf.sort_values(by="count", ascending=False).head(10)

# Plot with seaborn
plt.figure(figsize=(10, 6))
sns.barplot(x="count", y="charges", data=top10, palette="viridis")

plt.title("Top 10 Statutes by Count")
plt.xlabel("Count")
plt.ylabel("Charges")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\apaas\AppData\Local\Temp\ipykernel_10012\3443400025.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="count", y="charges", data=top10, palette="viridis")

# %%
plt.figure(figsize=(8, 8))
plt.pie(top10["count"], labels=top10["charges"], autopct="%1.1f%%", startangle=140, colors=sns.color_palette("pastel"))
plt.title("Top 10 Charges Distribution")
plt.show()

# %%
len(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(d)
#
# NameError: name 'd' is not defined
